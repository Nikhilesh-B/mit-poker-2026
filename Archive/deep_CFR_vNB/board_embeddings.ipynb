# %%
import torch 
from canon_cards import canon_cards

# %%
hand = ['8s','Ad','7s']
board = ['As','8h','7h','5s','Th','Ad']
o = canon_cards(hand=hand, board=board)


can_hand = o.get_canonical_hand_tensor()
print(can_hand)

can_board = o.get_canonical_board_tensor()
print(can_board)
# Out:
# tensor([140,  81,  71])
# tensor([141, 140, 102,  82,  72,  51])
