# %% [markdown]
# ### Inspecting MCCFR by hand to see how it works

# %%
import pickle

# %%
filepath = 'mccfr_strategy.pkl'
with open(filepath, 'rb') as f:
        strategy_data = pickle.load(f)

# %%
strategy_table = strategy_data['strategy_table']

strategy_table

print(len(strategy_table))
# Out:
# 25744636

# %%
print(strategy_table["S6|H:4s1,6s0|B:2s3,5s0,6s2,7s1,Js1,Ts0|A:rBrDXDXrrrrrrrr"])
# Out:
# defaultdict(<class 'float'>, {'RAISE_2': 0.2, 'RAISE_47': 0.2, 'RAISE_93': 0.2, 'CHECK': 2.2, 'FOLD': 10.433333333333334, 'RAISE_4': 0.8, 'RAISE_96': 0.2, 'RAISE_188': 0.5333333333333333, 'CALL': 8.233333333333334, 'RAISE_48': 0.2, 'RAISE_92': 0.5333333333333333, 'RAISE_49': 0.2, 'RAISE_94': 1.0666666666666667, 'RAISE_6': 0.4, 'RAISE_98': 0.2, 'RAISE_190': 0.5333333333333333, 'RAISE_24': 0.2, 'RAISE_45': 0.5333333333333333, 'RAISE_8': 0.2, 'RAISE_51': 0.2, 'RAISE_50': 0.2, 'RAISE_95': 0.5333333333333333})
