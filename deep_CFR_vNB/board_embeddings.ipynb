# %%
import torch 
from canon_cards import canon_cards

# %%
hand = ['8s','Ad','7s']
board = ['As','8h','7h']
o = canon_cards(hand=hand, board=board)

print(o.canonical_board)
print(o.canonical_hand)


hand = o.get_canonical_hand_tensor()
print(hand)
# Out:
# ['14s1', '8s2', '7s2']
# ['8s1', '14s0', '7s1']
# 14s0
# ['14', '0']
# 7s1
# ['7', '1']
# 8s1
# ['8', '1']
# tensor([140,  71,  81])
