# %%
from canocalization_board_cards import canon_cards



hand = ['8s','13d','7s']
board = ['13s','8h','7h']
o = canon_cards(hand=hand, board=board)
hand, board = canonicalize_cards(hand, board)

print(hand, board)
# Out:
# ['8s0', '13s2', '7s0'] ['13s0', '8s1', '7s1']
